# %%
import os
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import csv
from hanspell import spell_checker
import pandas as pd

# %% [markdown]
# # 자유게시판

# %%
options = Options()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\Users\beomh\Desktop",#이것도 바꿔야할듯 2
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

xpath_name = ['//*[@id="container"]/div[2]/article[1]','//*[@id="container"]/div[2]/article[2]','//*[@id="container"]/div[2]/article[3]','//*[@id="container"]/div[2]/article[4]',
              '//*[@id="container"]/div[2]/article[5]','//*[@id="container"]/div[2]/article[6]','//*[@id="container"]/div[2]/article[7]','//*[@id="container"]/div[2]/article[8]',
              '//*[@id="container"]/div[2]/article[9]','//*[@id="container"]/div[2]/article[10]','//*[@id="container"]/div[2]/article[11]','//*[@id="container"]/div[2]/article[12]',
               '//*[@id="container"]/div[2]/article[13]','//*[@id="container"]/div[2]/article[14]','//*[@id="container"]/div[2]/article[15]','//*[@id="container"]/div[2]/article[16]',
               '//*[@id="container"]/div[2]/article[17]','//*[@id="container"]/div[2]/article[18]','//*[@id="container"]/div[2]/article[19]','//*[@id="container"]/div[2]/article[20]']

f = open("애타_자유게시판.csv",'w',encoding='utf-8')
f.write("제목, 내용\n")



options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options = options)
driver.implicitly_wait(10)
driver.get('https://everytime.kr/login')

driver.find_element(By.XPATH,'//*[@id="container"]/form/p[1]/input').send_keys("bbh221")
driver.find_element(By.XPATH,'//*[@id="container"]/form/p[2]/input').send_keys("1q2w3e4r5t")
driver.find_element(By.XPATH,'//*[@id="container"]/form/p[3]/input').click()
#time.sleep(1)
driver.find_element(By.XPATH,'//*[@id="container"]/div[4]/div[1]/div/h3/a').click()
#driver.find_element(By.XPATH,'//*[@id="container"]/div[4]/div[4]/div/h3/a').click()
#time.sleep(1)
i=0
while i<100:
    if i==0:
        for j in range(20):
            test = driver.find_element(By.XPATH,xpath_name[j]).text
            #time.sleep(1)
            test_split = test.split('\n')
            f.write(test_split[0]+','+test_split[1]+'\n')
        driver.find_element(By.XPATH,'//*[@id="container"]/div[2]/div[2]/a').click()
        #time.sleep(0.5)
        i+=1
    
    elif i==1:
        for j in range(20):
            test = driver.find_element(By.XPATH,xpath_name[j]).text
            #time.sleep(1)
            test_split = test.split('\n')
            f.write(test_split[0]+','+test_split[1]+'\n')
        driver.find_element(By.XPATH,'//*[@id="container"]/div[2]/div[2]/a[2]').click()
        #time.sleep(0.5)
        i+=1
        
    else:
        for j in range(20):
            test = driver.find_element(By.XPATH,xpath_name[j]).text
            #time.sleep(1)
            test_split = test.split('\n')
            f.write(test_split[0]+','+test_split[1]+'\n')
        driver.find_element(By.XPATH,'//*[@id="container"]/div[2]/div[2]/a[3]').click()
        #time.sleep(0.5)
        i+=1
        
f.close()
print("완료")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [C:\Users\beomh\.wdm\drivers\chromedriver\win32\98.0.4758.102\chromedriver.exe] found in cache
# 완료

# %% [markdown]
# # 신입생 질문 스크랩

# %%
options = Options()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\Users\beomh\Desktop",#이것도 바꿔야할듯 2
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

xpath_name = ['//*[@id="container"]/div[3]/article[1]','//*[@id="container"]/div[3]/article[2]','//*[@id="container"]/div[3]/article[3]','//*[@id="container"]/div[3]/article[4]',
              '//*[@id="container"]/div[3]/article[5]','//*[@id="container"]/div[3]/article[6]','//*[@id="container"]/div[3]/article[7]','//*[@id="container"]/div[3]/article[8]',
              '//*[@id="container"]/div[3]/article[9]','//*[@id="container"]/div[3]/article[10]','//*[@id="container"]/div[3]/article[11]','//*[@id="container"]/div[3]/article[12]',
               '//*[@id="container"]/div[3]/article[13]','//*[@id="container"]/div[3]/article[14]','//*[@id="container"]/div[3]/article[15]','//*[@id="container"]/div[3]/article[16]',
               '//*[@id="container"]/div[3]/article[17]','//*[@id="container"]/div[3]/article[18]','//*[@id="container"]/div[3]/article[19]','//*[@id="container"]/div[3]/article[20]']

f = open("애타_100.csv",'w',encoding='utf-8')
f.write("제목, 내용\n")



options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options = options)
driver.implicitly_wait(10)
driver.get('https://everytime.kr/login')

driver.find_element(By.XPATH,'//*[@id="container"]/form/p[1]/input').send_keys("bbh221")
driver.find_element(By.XPATH,'//*[@id="container"]/form/p[2]/input').send_keys("1q2w3e4r5t")
driver.find_element(By.XPATH,'//*[@id="container"]/form/p[3]/input').click()
#time.sleep(1)
#driver.find_element(By.XPATH,'//*[@id="container"]/div[4]/div[1]/div/h3/a').click()
driver.find_element(By.XPATH,'//*[@id="container"]/div[4]/div[4]/div/h3/a').click()
#time.sleep(1)
i=0
while i<500:
    if i==0:
        for j in range(20):
            test = driver.find_element(By.XPATH,xpath_name[j]).text
            test_ch = test.replace(',',' ')
            test_split = test_ch.split('\n')
            f.write(test_split[1]+','+test_split[3]+'\n')
        driver.find_element(By.XPATH,'//*[@id="container"]/div[3]/div[2]/a').click()
        #time.sleep(0.5)
        i+=1
    
    elif i==1:
        for j in range(20):
            test = driver.find_element(By.XPATH,xpath_name[j]).text
            test_ch = test.replace(',',' ')
            test_split = test_ch.split('\n')
            f.write(test_split[1]+','+test_split[3]+'\n')
        driver.find_element(By.XPATH,'//*[@id="container"]/div[3]/div[2]/a[2]').click()
        #time.sleep(0.5)
        i+=1
        
    else:
        for j in range(20):
            test = driver.find_element(By.XPATH,xpath_name[j]).text
            test_ch = test.replace(',',' ')
            test_split = test_ch.split('\n')
            f.write(test_split[1]+','+test_split[3]+'\n')
        driver.find_element(By.XPATH,'//*[@id="container"]/div[3]/div[2]/a[3]').click()
        #time.sleep(0.5)
        i+=1
        
f.close()
print("완료")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [C:\Users\beomh\.wdm\drivers\chromedriver\win32\98.0.4758.102\chromedriver.exe] found in cache
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-c3eb906be742> in <module>
#      54     else:
#      55         for j in range(20):
# ---> 56             test = driver.find_element(By.XPATH,xpath_name[j]).text
#      57             test_ch = test.replace(',',' ')
#      58             test_split = test_ch.split('\n')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
# ...

# %% [markdown]
# # 네이버 기사

# %%
options = Options()
options.add_experimental_option("prefs", {
  "download.default_directory": r"C:\Users\beomh\Desktop",#이것도 바꿔야할듯 2
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

xpath_page = ['//*[@id="main_content"]/div[3]/a[1]','//*[@id="main_content"]/div[3]/a[2]','//*[@id="main_content"]/div[3]/a[3]','//*[@id="main_content"]/div[3]/a[4]',
              '//*[@id="main_content"]/div[3]/a[5]','//*[@id="main_content"]/div[3]/a[6]','//*[@id="main_content"]/div[3]/a[7]','//*[@id="main_content"]/div[3]/a[8]',
              '//*[@id="main_content"]/div[3]/a[9]','//*[@id="main_content"]/div[3]/a[10]','//*[@id="main_content"]/div[3]/a[11]']

xpath_news = ['//*[@id="main_content"]/div[2]/ul[1]/li[1]','//*[@id="main_content"]/div[2]/ul[1]/li[2]','//*[@id="main_content"]/div[2]/ul[1]/li[3]',
              '//*[@id="main_content"]/div[2]/ul[1]/li[4]','//*[@id="main_content"]/div[2]/ul[1]/li[5]','//*[@id="main_content"]/div[2]/ul[1]/li[6]',
              '//*[@id="main_content"]/div[2]/ul[1]/li[7]','//*[@id="main_content"]/div[2]/ul[1]/li[8]','//*[@id="main_content"]/div[2]/ul[1]/li[9]',
              '//*[@id="main_content"]/div[2]/ul[1]/li[10]','//*[@id="main_content"]/div[2]/ul[2]/li[1]','//*[@id="main_content"]/div[2]/ul[2]/li[2]',
              '//*[@id="main_content"]/div[2]/ul[2]/li[3]','//*[@id="main_content"]/div[2]/ul[2]/li[4]','//*[@id="main_content"]/div[2]/ul[2]/li[5]',
              '//*[@id="main_content"]/div[2]/ul[2]/li[6]','//*[@id="main_content"]/div[2]/ul[2]/li[7]','//*[@id="main_content"]/div[2]/ul[2]/li[8]',
              '//*[@id="main_content"]/div[2]/ul[2]/li[9]','//*[@id="main_content"]/div[2]/ul[2]/li[10]']

f = open("뉴스_정치.csv",'w',encoding='utf-8')
f.write("헤드라인, 내용, 출간 매체 \n")
#f.write("헤드라인\n")

options.add_argument("start-maximized")
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options = options)
driver.implicitly_wait(3)
driver.get('https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=265')
#네이버 기사 중 국회 정당 관련 부분




date = 0

while date<10:
    if date == 0:
        for i in range(10):
            for j in range(20):
                news = driver.find_element(By.XPATH,xpath_news[j]).text
                news_ch = news.replace(',',' ')
                news_split = news_ch.split('\n')
                if len(news_split) == 4:
                    f.write(news_split[1]+','+news_split[2]+','+news_split[3]+'\n')
                elif len(news_split)==2:
                    f.write(news_split[0]+','+'           '+','+news_split[1]+'\n')
                elif len(news_split) ==3:
                    f.write(news_split[0]+','+news_split[1]+','+news_split[2]+'\n')
            driver.find_element(By.XPATH,xpath_page[i]).click()

        while True:
            try:
                for i in range(1,11):
                    for j in range(20):
                        news = driver.find_element(By.XPATH,xpath_news[j]).text
                        news_ch = news.replace(',',' ')
                        news_split = news_ch.split('\n')
                        if len(news_split) == 4:
                            f.write(news_split[1]+','+news_split[2]+','+news_split[3]+'\n')
                        elif len(news_split)==2:
                            f.write(news_split[0]+','+'           '+','+news_split[1]+'\n')
                        elif len(news_split) ==3:
                            f.write(news_split[0]+','+news_split[1]+','+news_split[2]+'\n')
                    driver.find_element(By.XPATH,xpath_page[i]).click()
            except: 
                print('다음 날짜')
                print(date)
                break

        driver.find_element(By.XPATH,'//*[@id="main_content"]/div[4]/a[1]').click()
        date +=1
    elif date ==1:
        for i in range(10):
            for j in range(20):
                news = driver.find_element(By.XPATH,xpath_news[j]).text
                news_ch = news.replace(',',' ')
                news_split = news_ch.split('\n')
                if len(news_split) == 4:
                    f.write(news_split[1]+','+news_split[2]+','+news_split[3]+'\n')
                elif len(news_split)==2:
                    f.write(news_split[0]+','+'           '+','+news_split[1]+'\n')
                elif len(news_split) ==3:
                    f.write(news_split[0]+','+news_split[1]+','+news_split[2]+'\n')
            driver.find_element(By.XPATH,xpath_page[i]).click()

        while True:
            try:
                for i in range(1,11):
                    for j in range(20):
                        news = driver.find_element(By.XPATH,xpath_news[j]).text
                        news_ch = news.replace(',',' ')
                        news_split = news_ch.split('\n')
                        if len(news_split) == 4:
                            f.write(news_split[1]+','+news_split[2]+','+news_split[3]+'\n')
                        elif len(news_split)==2:
                            f.write(news_split[0]+','+'           '+','+news_split[1]+'\n')
                        elif len(news_split) ==3:
                            f.write(news_split[0]+','+news_split[1]+','+news_split[2]+'\n')
                    driver.find_element(By.XPATH,xpath_page[i]).click()
            except: 
                print('다음 날짜')
                print(date)
                break

        driver.find_element(By.XPATH,'//*[@id="main_content"]/div[4]/a[2]').click()
        date +=1
        
    else:
        for i in range(10):
            for j in range(20):
                news = driver.find_element(By.XPATH,xpath_news[j]).text
                news_ch = news.replace(',',' ')
                news_split = news_ch.split('\n')
                if len(news_split) == 4:
                    f.write(news_split[1]+','+news_split[2]+','+news_split[3]+'\n')
                elif len(news_split)==2:
                    f.write(news_split[0]+','+'           '+','+news_split[1]+'\n')
                elif len(news_split) ==3:
                    f.write(news_split[0]+','+news_split[1]+','+news_split[2]+'\n')
            driver.find_element(By.XPATH,xpath_page[i]).click()

        while True:
            try:
                for i in range(1,11):
                    for j in range(20):
                        news = driver.find_element(By.XPATH,xpath_news[j]).text
                        news_ch = news.replace(',',' ')
                        news_split = news_ch.split('\n')
                        if len(news_split) == 4:
                            f.write(news_split[1]+','+news_split[2]+','+news_split[3]+'\n')
                        elif len(news_split)==2:
                            f.write(news_split[0]+','+'           '+','+news_split[1]+'\n')
                        elif len(news_split) ==3:
                            f.write(news_split[0]+','+news_split[1]+','+news_split[2]+'\n')
                    driver.find_element(By.XPATH,xpath_page[i]).click()
            except: 
                print('다음 날짜')
                print(date)
                break

        driver.find_element(By.XPATH,'//*[@id="main_content"]/div[4]/a[3]').click()
        date +=1

f.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [C:\Users\beomh\.wdm\drivers\chromedriver\win32\98.0.4758.102\chromedriver.exe] found in cache
# 다음 날짜
# 0
# 다음 날짜
# 1
# 다음 날짜
# 2
# 다음 날짜
# 3
# 다음 날짜
# 4
# 다음 날짜
# 5
# 다음 날짜
# 6
# 다음 날짜
# 7
# 다음 날짜
# 8
# 다음 날짜
# 9
